# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random,string

plt.rcParams.update({'font.size': 8, 'font.family': 'sans'})

diabetes = pd.read_csv('diabetes.tab.csv')
print(diabetes.head())
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %% [markdown]
# Amounts

# %% [markdown]
# 1.1. Barplots
# <br>
# Aesthatics
# <ul>
# <li> X - Y Axis</li>
# <li>The Barplot represent the aggregate of the data like mean, median, precentile min, max not the amount of the data</li>
# </ul>

# %%
data = (1,2,4,7,9,14)
data_idx = ('A','B','C','D','E','F')
data = pd.Series(data, index=data_idx)
ax = sns.barplot(data, orient='v') 
for i in ax.containers: ax.bar_label(i)
plt.show()

# %% [markdown]
# 1.2. Horizontal Bar

# %% [markdown]
# Same as Bar Plot, but presented horizontally
# <br>
# The Y Axis is the X of bar plot
# <br>
# The X Axis represent the data --> Y Axis

# %%
data = (1,2,4,7,9,14)
data_idx = ('A','B','C','D','E','F')
data = pd.Series(data, index=data_idx)
ax = sns.barplot(data, orient='h') 
for i in ax.containers: ax.bar_label(i)
plt.show()

# %%
# --------------------------------------------------------------
# Contoh penggunaan barplot untuk amount dengan tipe lainnya
# --------------------------------------------------------------
plt.figure(figsize=(15,6))
sns.barplot(diabetes, x='AGE', y='BP',estimator='mean',errorbar='sd')
plt.show()

# the line in the bar is the standard deviation
# bar plot can only show std,mean,median

# %% [markdown]
# 1.1.1.1 CountPlot
# <br>
# Countplot is used for counting the frequency, basically it's a bar plot

# %%
# frequency 

plt.figure(figsize=(15,6))
sns.countplot(diabetes, x='AGE', stat='count')
plt.title('1-1. Number of Diabetes Patients by Age')
plt.yticks(range(0, 20,2))
plt.show()

# %% [markdown]
# 1.3 Dot Plot

# %% [markdown]
# Aesthatics:
# <ul>
# <li>X-Y Axis</li>
# </ul>

# %%
data = (1,2,4,7,9,14)
data_idx = ('A','B','C','D','E','F')
data = pd.Series(data, index=data_idx)
plt.plot(data_idx, data, marker='o', linestyle='none')
plt.title('1-3. An example of Dot Plot')
plt.show()

# %% [markdown]
# 1.4. Heatmap
#
# Data Type
# <ul>
# <li> X,Y discreete data </li>
# <li> The cell represent the continous data </li>
# </ul>
#
# Aesthaetics
# <ul>
# <li> X,Y Axis </li>
# <li> The color represent inside the map --> the color is in one color range</li>
# </ul>

# %%
#Heatmap is not easy for multi data 

# x,y --> Discreete
# the cell is the continous data

def random_string(length):
    return ''.join(random.choice(string.ascii_lowercase) for i in range(length))

columns = [random_string(5) for i in range(0,15)]
rows = [random_string(5) for i in range(0,25)]
data = pd.DataFrame(np.random.randint(0,100,size=(25, 15)), columns=columns, index=rows)
print(data.head())
plt.figure(figsize=(15,6))
sns.heatmap(data, cmap="magma")
plt.show()
# Out:
#        fsyhs  rlmte  cyuln  htpac  fxgvo  kyspm  cwlsy  sgcjj  terrr  rraau  \
# vbvmn     82     72     58     76     75     81     99      8     76     88
# qeynu     57     88     58     31     94     98     93     53     56     12
# ioiaw      1     12      3      0     92     75     48     45     43     94
# haxuz     55     52     27     78      8     21     88     56     69     45
# zugby     77     36     97     61     81     70     87     37     52     16
#
#        fmhim  hdevr  lnyrv  ilstc  xyyrt
# vbvmn     66     52     70     37      4
# qeynu     33     11     64     30     21
# ioiaw     45     42     50     43     81
# haxuz      0     91     91     32     58
# zugby     78     51     71     25     47

# %% [markdown]
# 1.5 Group Bar Plot

# %% [markdown]
# Group Bar is bar plot that can  be used to differentiate 2 category in one category (2 type of data), represent side-by-side
#
# Aesthaetics --> same as Bar Plot
#
# Color/Hue can be used to differenciate the 2 category

# %%
plt.figure(figsize=(15,6))
sns.countplot(diabetes, x='AGE', hue='SEX')
plt.title('1-5. Number of Diabetes Patients by Age and Sex')
plt.show()

# %%
# --------------------------------------------------------------
# Contoh 1-5
# --------------------------------------------------------------
plt.figure(figsize=(15, 6))
sns.barplot(diabetes.loc[10:50,:], x='AGE', y='BMI', hue='SEX', errorbar=('sd',.5),capsize=.2)
plt.title('1-5. Number of Diabetes Patients by Age and Sex')
plt.show()

# %% [markdown]
# 1.6. Stacked Bar Plot

# %% [markdown]
# Like Bar Grouped bar plot, but the data is represented in stack
#
# Stack has a weakness in interpretation, wheter the data on the top is started from zero or started from the top of the data

# %%
# --------------------------------------------------------------
# Contoh 1-6
# --------------------------------------------------------------
x = ['AAA','BBB','CCC','DDD','EEE','FFF']
data = {'A': [1,2,4,7,9,14], 'B': [3,1,5,3,5,6]}
bottom = [0,0,0,0,0,0]    # np.zeroes(3)
# 1 function inside of a loop
for key,val in data.items():
    plt.bar(x, val, label=key, bottom=bottom)
    bottom = [bottom[i] + val[i] for i in range(len(bottom))]
plt.yticks(range(0, 21))
plt.title("1-6 Stacked Bar")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# 2. Distributions

# %% [markdown]
# 2.1. Histogram

# %% [markdown]
# Histogram is used to visualize the distribution of the data, there are many type of historam just change the multiple (for multiple cat)
#
# Aesthaetics:
# <ul>
# <li>X-Y Axix</li>
# </ul>

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=False, constrained_layout = True)
fig.set_figheight(6)
fig.set_figwidth(15)

# difference == hue
sns.histplot(diabetes, x='AGE', hue='SEX', multiple='layer', bins=18, stat='count', ax=ax[0,0])
ax[0,0].set_xlabel('layer')
sns.histplot(diabetes, x='AGE', hue='SEX', multiple='dodge', bins=18, stat='count', ax=ax[0,1])
ax[0,1].set_xlabel('dodge')
sns.histplot(diabetes, x='AGE', hue='SEX', multiple='stack', bins=18, stat='count', ax=ax[1,0])
ax[1,0].set_xlabel('stack')
sns.histplot(diabetes, x='AGE', hue='SEX', multiple='fill', bins=18, stat='count', ax=ax[1,1])
ax[1,1].set_xlabel('fill')

plt.suptitle('Histogram', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# 2.2.Density Plot

# %% [markdown]
# The Density is based on the density of the data
#
# Aesthetic
# <ul>
# <li> X-Y Axis</li>
# </ul>

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=False, constrained_layout = True)
sns.kdeplot(diabetes, x='AGE', hue='SEX', multiple='layer', ax=ax[0,0])
ax[0,0].set_xlabel('layer')
sns.kdeplot(diabetes, x='AGE', hue='SEX', multiple='stack', ax=ax[0,1])
ax[0,1].set_xlabel('stack')
sns.kdeplot(diabetes, x='AGE', hue='SEX', multiple='fill', ax=ax[1,0])
ax[1,0].set_xlabel('fill')
ax[1,1].axis('off')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.suptitle('KDE (Density)', fontsize=14, fontweight='bold')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 2.3 ECDF Plot

# %%
sns.ecdfplot(diabetes, x='BP')
plt.show()

# %% [markdown]
# 2.4. QQ-Plot

# %%
import statsmodels.api as sm

# Membuat distribusi normal secara acak dengan mean=50, dan standar deviasi 5
data = np.random.normal(50, 5, 1000) # (mean, std, size)

# Bandingkan distribusi di atas dengan distribusi normal yg standar menggunakan QQ plot
# Skala x dan y berbeda (perhatikan bahwa sumbu y perlu diubah ke 
# mean dan standar deviasi agar bisa dibandingkan dengan sumbu x)
sm.qqplot(data, line='45') # line = 45,s,r,q,None
plt.show()

# %% [markdown]
# 2.5 Box Plot

# %% [markdown]
# <ul>
# <li> Easy to program, but hard to understand </li>
# <li> the upper show the upper percentile </li>
# <li> the lower show the lower percentile </li>
# <li> the dot show the outlier </li>

# %%
# --------------------------------------------------------------

# --------------------------------------------------------------
plt.figure(figsize=(35,16))
sns.catplot(diabetes,x='AGE',y='BMI',kind='box')
plt.show()

# %%
sns.catplot(diabetes,x='AGE',y='BMI',hue='SEX', kind='box')
plt.show()

# %% [markdown]
# 2.6. Violin Plot

# %%
diabetes = diabetes.loc[(diabetes['AGE'] >= 30) & (diabetes['AGE'] < 50)] 
sns.catplot(diabetes,x='AGE',y='BMI',kind='violin')
plt.show()
sns.catplot(diabetes,x='AGE',y='BMI',hue='SEX', kind='violin')
plt.show()

# %% [markdown]
# 2.7. Strip Chart

# %%
plt.figure(figsize=(10, 6))
diabetes = diabetes.loc[(diabetes['AGE'] >= 30) & (diabetes['AGE'] < 50)] 
sns.swarmplot(diabetes, x="AGE", y="BMI",hue='SEX',size=4)
plt.show()

# %% [markdown]
# 2.8.  Sina Plot
# <br>
# merge between violin and strip chart

# %%
diabetes = diabetes.loc[(diabetes['AGE'] >= 30) & (diabetes['AGE'] < 50)] 
sns.catplot(diabetes,x='AGE',y='BMI',kind='violin')
sns.swarmplot(diabetes, x="AGE", y="BMI",hue='SEX',size=4)
plt.show()
# Out:
# c:\Users\Alfred\anaconda3\envs\kuliah\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 2.11 Ridgeline

# %%
# Membuat contoh data berupa sebuah dataframe dengan 250 baris (integer) dan 2 kolom ()
isibaris = np.random.randn(250)
isikolom = np.tile(['A','B','C','D','E'], 50)   # ['A','B','C','D','E','A','B','C','D','E',...]
df = pd.DataFrame(dict(x=isibaris, y=isikolom))
print(df.head(20))
# ... geser data ke kanan sesuai isi kolom y
df['x'] = np.where(df['y'] =='A', df['x']+1,df['x'])
df['x'] = np.where(df['y'] =='B', df['x']+2,df['x'])
df['x'] = np.where(df['y'] =='C', df['x']+3,df['x'])
df['x'] = np.where(df['y'] =='D', df['x']+4,df['x'])
df['x'] = np.where(df['y'] =='E', df['x']+5,df['x'])
# print(df.head(25))

sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# siapkan tempat utk beberapa plot sesuai isi kolom 'y'
fg = sns.FacetGrid(df, row="y", hue="y", aspect=7, height=1)  #any plot will be shown in different area, seperated by y
# buat density plot pertama dengan fill=true, dan yg kedua dengan garis tepi berwarna putih
fg.map(sns.kdeplot, "x", bw_adjust=.5, clip_on=False, fill=True, alpha=0.8, linewidth=1.5)
#show the column=
fg.map(sns.kdeplot, "x", bw_adjust=.5, color='white')
#show the white line 
# kurangi jarak antar plot
fg.figure.subplots_adjust(hspace=-.2)


fg.set_titles("")              # hilangkan judul tiap plot
fg.set(yticks=[], ylabel="")   # hilangkan tick dan label dari sumbu y di tiap plot
fg.despine(left=True)          # hilangkan garis untuk skala y
plt.show()
# Out:
#            x  y
# 0   0.873943  A
# 1  -0.170314  B
# 2  -0.556701  C
# 3   0.677152  D
# 4   1.428249  E
# 5  -0.689835  A
# 6   1.406611  B
# 7  -0.466583  C
# 8  -0.325577  D
# 9  -0.565261  E
# 10 -0.531852  A
# 11 -1.255815  B
# 12 -1.168518  C
# 13 -0.244858  D
# 14 -0.980990  E
# 15  0.735313  A
# 16 -0.067415  B
# 17  1.160862  C
# 18  1.492730  D
# 19 -0.015608  E

# %% [markdown]
# PairPlot
# <li> Used More often than scatterplot

# %%
diag = sns.pairplot(diabetes, 
             x_vars=('AGE','BMI','BP'), 
             y_vars=('AGE','BMI','BP'), 
             hue='SEX',  
             kind='scatter',diag_kind='kde')
diag._legend.set_bbox_to_anchor((0.6, 0.6))
plt.show()

diag = sns.pairplot(diabetes, 
             x_vars=('AGE','BMI','BP'), 
             y_vars=('AGE','BMI','BP'), 
             hue='SEX',  
             kind='kde',diag_kind='kde')
diag._legend.set_bbox_to_anchor((0.6, 0.6))
plt.show()

diag = sns.pairplot(diabetes, 
             x_vars=('AGE','BMI','BP'), 
             y_vars=('AGE','BMI','BP'), 
             hue='SEX',  
             kind='hist',diag_kind='kde')
diag._legend.set_bbox_to_anchor((0.6, 0.6))
plt.show()

# %% [markdown]
# 3. Proportions
# <br>    Representing the proportion of the data

# %% [markdown]
#         3.1 Pie Chart
#         <br>

# %%
data = [25,30,35,5,5]
labels = ['AAA','BBB','CCC','DDD','EEE']

# Starangle the starting point of the pie chart
plt.pie(data, labels=labels, startangle=50, explode = [0, 0.2, 0, 0.5, 0], autopct='%.2f%%')
plt.show()

# %% [markdown]
#         3.4. Multiple Pie Charts
#         Like pie plot but just using subplot, display some number of plot in one plot

# %%
data1 = [25,30,35,5,5]
data2 = [10,35,5,5,45]
data3 = [32,18,27,12,11]
labels = ['AAA','BBB','CCC','DDD','EEE']

plt.figure(figsize=(20,16))
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=False, sharey=False, constrained_layout = True)

ax[0].pie(data1, labels=labels, startangle=45, explode = [0, 0, 0, 0.2, 0], autopct='%.2f%%')
ax[1].pie(data2, labels=labels, startangle=120, explode = [0, 0, 0, 0.2, 0], autopct='%.2f%%')
ax[2].pie(data3, labels=labels, startangle=0, explode = [0, 0, 0, 0.2, 0], autopct='%.2f%%')
plt.show()

# %% [markdown]
#         3.7. Mosaic Plots
# Create Fragment of data by the x-axis and y-axis
# <br>
# Show The relationship of 2 variable

# %%
from statsmodels.graphics.mosaicplot import mosaic
data = {('a', 'b'): 9, ('a', 'c'): 14, ('d', 'b'): 27, ('d', 'c'): 5}
props={}
props[('a','b')]={'facecolor':'green', 'edgecolor':'white'}
props[('a','c')]={'facecolor':'red', 'edgecolor':'white'}
props[('d','b')]={'facecolor':'xkcd:aqua','edgecolor':'white'}
props[('d','c')]={'facecolor':'xkcd:red','edgecolor':'white'}
labelizer=lambda k:{('a','b'):9,('a','c'):14,('d','b'):27,('d','c'):5}[k]
# a function to simplify thing, the k is ued to solve the function
mosaic(data, gap=0, title='a mosaic plot',properties=props, labelizer=labelizer)
plt.show()

# %% [markdown]
#         3.8. Treemap
# Similar to mosaic plot
# <ul>
# <li> No Axis is Used
# <li> Boxes inside Boxes

# %%
import plotly.express as px
datax = { 'kota' : ['Surabaya','Surabaya','Jakarta','Jakarta','Bandung','Bandung'],
          'penduduk' : ['Penduduk','Penduduk','Bukan','Penduduk','Bukan','Penduduk'], 
          'JnsKelamin' : ['L','P','P','P','L','L'],
           'ratagaji' : [1000,2000,3000,4000,5000,6000] } 
data = pd.DataFrame(data=datax)
fig = px.treemap(data, path=['kota', 'penduduk','JnsKelamin'], values='ratagaji')
fig.show()

# %% [markdown]
#         3.9. Parallel set
# Easier to understand more than the treemap

# %%
import plotly.express as px

datax = { 'kota' : ['Surabaya','Surabaya','Jakarta','Jakarta','Bandung','Bandung'],
          'penduduk' : ['Ya','Ya','Tidak','Ya','Tidak','Tidak'], 
          'JnsKelamin' : ['L','P','P','L','P','L'] } 
data = pd.DataFrame(data=datax)
print(data)

fig = px.parallel_categories(data, dimensions=['kota','penduduk','JnsKelamin'])
fig.show()
# Out:
#        kota penduduk JnsKelamin
# 0  Surabaya       Ya          L
# 1  Surabaya       Ya          P
# 2   Jakarta    Tidak          P
# 3   Jakarta       Ya          L
# 4   Bandung    Tidak          P
# 5   Bandung    Tidak          L
